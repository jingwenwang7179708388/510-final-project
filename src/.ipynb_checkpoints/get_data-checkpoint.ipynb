# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.amazon.com/dp/B08P2C4SM6/ref=sspa_dk_rhf_yoy_pt_sub_2/?_encoding=UTF8&ie=UTF8&psc=1&sp_csd=d2lkZ2V0TmFtZT1zcF9yaGZfeW95&pd_rd_w=BS9ka&content-id=amzn1.sym.87a48bff-0d65-465c-9848-dfd8668d09df&pf_rd_p=87a48bff-0d65-465c-9848-dfd8668d09df&pf_rd_r=0YA6CCATH8B0QBNVCQ3S&pd_rd_wg=Ht0OD&pd_rd_r=44bcf393-a03f-4852-ae69-7fc6b7193266&ref_=sspa_dk_rhf_yoy_pt_sub"
r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")

soup.select(".class-name")
# Out:
# []
